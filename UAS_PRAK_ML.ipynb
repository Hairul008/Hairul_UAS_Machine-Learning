# %% [markdown]
# <a href="https://colab.research.google.com/github/Hairul008/Hairul_UAS_Machine-Learning/blob/main/UAS_PRAK_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.datasets import load_iris

# %%
# Memuat dataset Iris
iris = load_iris()
data = pd.DataFrame(data=iris.data, columns=iris.feature_names)
data['target'] = iris.target

# %%
# Menampilkan beberapa baris data
print(data.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# Memeriksa nilai yang hilang
print(data.isnull().sum())
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# Memisahkan fitur dan target
X = data[iris.feature_names]
y = data['target']

# Membagi data ke dalam set pelatihan dan pengujian
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print(f'Jumlah data pelatihan: {len(X_train)}')
print(f'Jumlah data pengujian: {len(X_test)}')
# Out:
# Jumlah data pelatihan: 105
# Jumlah data pengujian: 45

# %%
from sklearn.tree import DecisionTreeClassifier

# Inisialisasi model
model = DecisionTreeClassifier(random_state=42)

# Melatih model
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
from sklearn.metrics import accuracy_score, classification_report

# Memprediksi hasil untuk data pengujian
y_pred = model.predict(X_test)

# Evaluasi model
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f'Akurasi: {accuracy}')
print('Laporan Klasifikasi:')
print(report)
# Out:
# Akurasi: 1.0
# Laporan Klasifikasi:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# Visualisasi pohon keputusan
plt.figure(figsize=(10,10))
plot_tree(model, feature_names=iris.feature_names, class_names=iris.target_names, filled=True)
plt.show()
